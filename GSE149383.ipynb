# %%
from Train2 import Train
results_GSE149383, scores_df_GSE149383 = Train(S='GSE149383')
# Out:
# N 0, Epoch 1/10, fold 1/5, Link label Loss: 0.8920960426330566, Link link Loss: 8.404730796813965
# AUC: 0.35416666666666663
# AUPR: 0.3605027922962706
# Best Threshold: inf
# Accuracy: 0.5714285714285714
# precision: 0.0
# F1 Score: 0.0
# /root/miniconda3/envs/myconda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# N 0, Epoch 1/10, fold 2/5, Link label Loss: 0.8030720949172974, Link link Loss: 7.521258354187012
# AUC: 0.6581632653061225
# AUPR: 0.69437844611849
# Best Threshold: -0.9807534
# Accuracy: 0.6785714285714286
# precision: 0.6086956521739131
# F1 Score: 0.7567567567567568
# N 0, Epoch 1/10, fold 3/5, Link label Loss: 0.6835283041000366, Link link Loss: 6.921087741851807
# AUC: 0.6153846153846153
# AUPR: 0.668544795168836
# ...
